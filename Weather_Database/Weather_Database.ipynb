# %%
# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kudahuvadhoo
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | te anau
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | ellisras
# Processing Record 6 of Set 1 | carutapera
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 1 | maniitsoq
# Processing Record 13 of Set 1 | bubaque
# Processing Record 14 of Set 1 | atikokan
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | leninskoye
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | abbotsford
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | swan river
# Processing Record 22 of Set 1 | nemuro
# Processing Record 23 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | bereda
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 1 | palmer
# Processing Record 30 of Set 1 | souillac
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | maketu
# Processing Record 35 of Set 1 | challans
# Processing Record 36 of Set 1 | tezu
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | kumluca
# Processing Record 43 of Set 1 | khandbari
# Processing Record 44 of Set 1 | korla
# Processing Record 45 of Set 1 | manggar
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | rio grande
# Processing Record 48 of Set 1 | lasa
# Processing Record 49 of Set 1 | marsabit
# Processing Record 50 of Set 1 | bhuban
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 2 | ahipara
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | sitka
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | opuwo
# Processing Record 9 of Set 2 | karratha
# Processing Record 10 of Set 2 | kahului
# Processing Record 11 of Set 2 | les cayes
# Processing Record 12 of Set 2 | beyneu
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | puerto madero
# Processing Record 17 of Set 2 | grindavik
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | hami
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | emerald
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | merauke
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | praia
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | hornostayivka
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 2 | kawalu
# Processing Record 34 of Set 2 | lima
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | chancay
# Processing Record 37 of Set 2 | tigil
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | dwarka
# Processing Record 40 of Set 2 | uk
# City not found. Skipping...
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | grand gaube
# Processing Record 43 of Set 2 | kununurra
# Processing Record 44 of Set 2 | ransang
# Processing Record 45 of Set 2 | flinders
# Processing Record 46 of Set 2 | surat
# Processing Record 47 of Set 2 | nishihara
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | nuuk
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | yeppoon
# Processing Record 2 of Set 3 | vigrestad
# Processing Record 3 of Set 3 | khasan
# Processing Record 4 of Set 3 | astipalaia
# City not found. Skipping...
# Processing Record 5 of Set 3 | camacari
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | saint-pierre
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 3 | olecko
# Processing Record 11 of Set 3 | pangai
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | ritchie
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | los llanos de aridane
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | loei
# Processing Record 18 of Set 3 | okhotsk
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | itaueira
# Processing Record 24 of Set 3 | weinan
# Processing Record 25 of Set 3 | coahuayana
# Processing Record 26 of Set 3 | ljubuski
# Processing Record 27 of Set 3 | dovhe
# Processing Record 28 of Set 3 | changping
# Processing Record 29 of Set 3 | sakakah
# Processing Record 30 of Set 3 | menongue
# Processing Record 31 of Set 3 | tazovskiy
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | padang
# Processing Record 34 of Set 3 | barquisimeto
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | jamestown
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | iwanai
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | highview
# Processing Record 46 of Set 3 | marsh harbour
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | sampit
# Processing Record 49 of Set 3 | pampa
# Processing Record 50 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 4 | lusaka
# Processing Record 2 of Set 4 | banes
# Processing Record 3 of Set 4 | naze
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | yatou
# Processing Record 6 of Set 4 | novikovo
# Processing Record 7 of Set 4 | mamou
# Processing Record 8 of Set 4 | sawtell
# Processing Record 9 of Set 4 | severomuysk
# Processing Record 10 of Set 4 | bilma
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | pacific grove
# Processing Record 14 of Set 4 | siniscola
# Processing Record 15 of Set 4 | soyo
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | loncoche
# Processing Record 18 of Set 4 | chuy
# Processing Record 19 of Set 4 | bom jesus
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | rocha
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | komsomolskiy
# Processing Record 24 of Set 4 | acapulco
# Processing Record 25 of Set 4 | rorvik
# Processing Record 26 of Set 4 | divo
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | lazaro cardenas
# Processing Record 29 of Set 4 | edd
# Processing Record 30 of Set 4 | eucaliptus
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | sioux lookout
# Processing Record 33 of Set 4 | kaeo
# Processing Record 34 of Set 4 | general higinio morinigo
# Processing Record 35 of Set 4 | mabaruma
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | peniche
# Processing Record 38 of Set 4 | richards bay
# Processing Record 39 of Set 4 | nelson bay
# Processing Record 40 of Set 4 | hamilton
# Processing Record 41 of Set 4 | waipawa
# Processing Record 42 of Set 4 | upernavik
# Processing Record 43 of Set 4 | santa vitoria do palmar
# Processing Record 44 of Set 4 | chara
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | neumunster
# Processing Record 47 of Set 4 | marsaxlokk
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | usinsk
# Processing Record 50 of Set 4 | denpasar
# Processing Record 1 of Set 5 | hanting
# Processing Record 2 of Set 5 | mariveles
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | bonthe
# Processing Record 6 of Set 5 | puerto ayora
# Processing Record 7 of Set 5 | hofn
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | yarmouth
# Processing Record 10 of Set 5 | yining
# Processing Record 11 of Set 5 | mwinilunga
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | smithers
# Processing Record 14 of Set 5 | fairbanks
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | mayo
# Processing Record 17 of Set 5 | abu samrah
# Processing Record 18 of Set 5 | laguna
# Processing Record 19 of Set 5 | dhidhdhoo
# Processing Record 20 of Set 5 | santa ana
# Processing Record 21 of Set 5 | priyutnoye
# Processing Record 22 of Set 5 | sorland
# Processing Record 23 of Set 5 | pitimbu
# Processing Record 24 of Set 5 | koungou
# Processing Record 25 of Set 5 | thinadhoo
# Processing Record 26 of Set 5 | semey
# Processing Record 27 of Set 5 | the pas
# Processing Record 28 of Set 5 | hobart
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | taree
# Processing Record 32 of Set 5 | visby
# Processing Record 33 of Set 5 | mao
# Processing Record 34 of Set 5 | canton
# Processing Record 35 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 5 | mindelo
# Processing Record 37 of Set 5 | tornio
# Processing Record 38 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 5 | boa esperanca
# Processing Record 40 of Set 5 | klungkung
# Processing Record 41 of Set 5 | kenai
# Processing Record 42 of Set 5 | galveston
# Processing Record 43 of Set 5 | marzuq
# Processing Record 44 of Set 5 | luwuk
# Processing Record 45 of Set 5 | san cristobal
# Processing Record 46 of Set 5 | saskylakh
# Processing Record 47 of Set 5 | mpongwe
# Processing Record 48 of Set 5 | viransehir
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | berbera
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | tuktoyaktuk
# Processing Record 4 of Set 6 | grand-santi
# Processing Record 5 of Set 6 | pemberton
# Processing Record 6 of Set 6 | leiyang
# Processing Record 7 of Set 6 | orlik
# Processing Record 8 of Set 6 | princeton
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | bonavista
# Processing Record 11 of Set 6 | kiunga
# Processing Record 12 of Set 6 | andenes
# Processing Record 13 of Set 6 | paramonga
# Processing Record 14 of Set 6 | nouadhibou
# Processing Record 15 of Set 6 | bagdarin
# Processing Record 16 of Set 6 | navirai
# Processing Record 17 of Set 6 | beipiao
# Processing Record 18 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 6 | leningradskiy
# Processing Record 20 of Set 6 | haverhill
# Processing Record 21 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 6 | port augusta
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | maicao
# Processing Record 25 of Set 6 | aktau
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | sayan
# Processing Record 29 of Set 6 | ostrovnoy
# Processing Record 30 of Set 6 | tucurui
# Processing Record 31 of Set 6 | yellamanchili
# City not found. Skipping...
# Processing Record 32 of Set 6 | florence
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | krasnoselkup
# Processing Record 35 of Set 6 | dunedin
# Processing Record 36 of Set 6 | cabo san lucas
# Processing Record 37 of Set 6 | tunduma
# Processing Record 38 of Set 6 | finschhafen
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | havelock
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | mar del plata
# Processing Record 43 of Set 6 | gimli
# Processing Record 44 of Set 6 | amga
# Processing Record 45 of Set 6 | chapais
# Processing Record 46 of Set 6 | birao
# Processing Record 47 of Set 6 | kaitangata
# Processing Record 48 of Set 6 | skovde
# City not found. Skipping...
# Processing Record 49 of Set 6 | nyakabindi
# Processing Record 50 of Set 6 | dongsheng
# Processing Record 1 of Set 7 | nome
# Processing Record 2 of Set 7 | elizabeth city
# Processing Record 3 of Set 7 | brazzaville
# Processing Record 4 of Set 7 | boyuibe
# Processing Record 5 of Set 7 | deputatskiy
# Processing Record 6 of Set 7 | waingapu
# Processing Record 7 of Set 7 | obigarm
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | mehamn
# Processing Record 10 of Set 7 | cayenne
# Processing Record 11 of Set 7 | baherden
# Processing Record 12 of Set 7 | vestmanna
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 16 of Set 7 | sheregesh
# Processing Record 17 of Set 7 | banda aceh
# Processing Record 18 of Set 7 | cabedelo
# Processing Record 19 of Set 7 | maragogi
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | cascais
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | ardakan
# Processing Record 24 of Set 7 | kattivakkam
# Processing Record 25 of Set 7 | kalangala
# Processing Record 26 of Set 7 | ketchikan
# Processing Record 27 of Set 7 | ratnagiri
# Processing Record 28 of Set 7 | swellendam
# Processing Record 29 of Set 7 | sergeyevka
# Processing Record 30 of Set 7 | casma
# Processing Record 31 of Set 7 | itaqui
# Processing Record 32 of Set 7 | namwala
# Processing Record 33 of Set 7 | axim
# Processing Record 34 of Set 7 | sao joao da barra
# Processing Record 35 of Set 7 | paringao
# Processing Record 36 of Set 7 | somerville
# Processing Record 37 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | neyshabur
# Processing Record 39 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 40 of Set 7 | meulaboh
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | perth
# Processing Record 43 of Set 7 | goderich
# Processing Record 44 of Set 7 | mosquera
# Processing Record 45 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 7 | kabalo
# Processing Record 47 of Set 7 | kampot
# Processing Record 48 of Set 7 | ambon
# Processing Record 49 of Set 7 | bubanza
# Processing Record 50 of Set 7 | arona
# Processing Record 1 of Set 8 | batemans bay
# Processing Record 2 of Set 8 | requena
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | tarata
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | ilhabela
# Processing Record 7 of Set 8 | machiques
# Processing Record 8 of Set 8 | trat
# Processing Record 9 of Set 8 | batagay-alyta
# Processing Record 10 of Set 8 | juba
# Processing Record 11 of Set 8 | pangnirtung
# Processing Record 12 of Set 8 | lexington park
# Processing Record 13 of Set 8 | narsaq
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | tabou
# Processing Record 16 of Set 8 | aquiraz
# Processing Record 17 of Set 8 | bacolod
# Processing Record 18 of Set 8 | morant bay
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | dzilam gonzalez
# Processing Record 23 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 8 | puerto penasco
# Processing Record 25 of Set 8 | antigonish
# Processing Record 26 of Set 8 | sisimiut
# Processing Record 27 of Set 8 | irbit
# Processing Record 28 of Set 8 | houston
# Processing Record 29 of Set 8 | kieta
# Processing Record 30 of Set 8 | fonte boa
# Processing Record 31 of Set 8 | praia da vitoria
# Processing Record 32 of Set 8 | tarakan
# Processing Record 33 of Set 8 | naryan-mar
# Processing Record 34 of Set 8 | pyaozerskiy
# Processing Record 35 of Set 8 | faya
# Processing Record 36 of Set 8 | nouakchott
# Processing Record 37 of Set 8 | den helder
# Processing Record 38 of Set 8 | collie
# Processing Record 39 of Set 8 | zhigansk
# Processing Record 40 of Set 8 | hit
# Processing Record 41 of Set 8 | fallon
# Processing Record 42 of Set 8 | shetpe
# Processing Record 43 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 8 | arraial do cabo
# Processing Record 45 of Set 8 | sibolga
# Processing Record 46 of Set 8 | pacifica
# Processing Record 47 of Set 8 | mancio lima
# Processing Record 48 of Set 8 | mobaye
# Processing Record 49 of Set 8 | isangel
# Processing Record 50 of Set 8 | kadaya
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | port keats
# Processing Record 4 of Set 9 | santo domingo
# Processing Record 5 of Set 9 | olinda
# Processing Record 6 of Set 9 | saint-augustin
# Processing Record 7 of Set 9 | tula
# Processing Record 8 of Set 9 | tres picos
# Processing Record 9 of Set 9 | zyryanka
# Processing Record 10 of Set 9 | vanimo
# Processing Record 11 of Set 9 | baie-saint-paul
# Processing Record 12 of Set 9 | anahuac
# Processing Record 13 of Set 9 | svetlogorsk
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | husavik
# Processing Record 16 of Set 9 | parry sound
# Processing Record 17 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 9 | noumea
# Processing Record 19 of Set 9 | concordia
# Processing Record 20 of Set 9 | ivanjica
# Processing Record 21 of Set 9 | natal
# Processing Record 22 of Set 9 | sylvan lake
# Processing Record 23 of Set 9 | mogadishu
# Processing Record 24 of Set 9 | karpathos
# Processing Record 25 of Set 9 | ranst
# Processing Record 26 of Set 9 | black river
# Processing Record 27 of Set 9 | envira
# Processing Record 28 of Set 9 | kolyvan
# Processing Record 29 of Set 9 | chokwe
# Processing Record 30 of Set 9 | medicine hat
# Processing Record 31 of Set 9 | mbandaka
# Processing Record 32 of Set 9 | poyarkovo
# Processing Record 33 of Set 9 | roald
# Processing Record 34 of Set 9 | leh
# Processing Record 35 of Set 9 | canakkale
# Processing Record 36 of Set 9 | jamame
# Processing Record 37 of Set 9 | madona
# Processing Record 38 of Set 9 | simpang
# Processing Record 39 of Set 9 | viedma
# Processing Record 40 of Set 9 | pisco
# Processing Record 41 of Set 9 | qui nhon
# Processing Record 42 of Set 9 | frolovo
# Processing Record 43 of Set 9 | vestmannaeyjar
# Processing Record 44 of Set 9 | maralal
# Processing Record 45 of Set 9 | nanyuki
# Processing Record 46 of Set 9 | chengde
# Processing Record 47 of Set 9 | los andes
# Processing Record 48 of Set 9 | humaita
# Processing Record 49 of Set 9 | bull savanna
# Processing Record 50 of Set 9 | zyuzelskiy
# Processing Record 1 of Set 10 | murchison
# Processing Record 2 of Set 10 | muisne
# Processing Record 3 of Set 10 | avera
# Processing Record 4 of Set 10 | bambanglipuro
# Processing Record 5 of Set 10 | vanderbijlpark
# Processing Record 6 of Set 10 | sapa
# Processing Record 7 of Set 10 | lethem
# Processing Record 8 of Set 10 | asfi
# Processing Record 9 of Set 10 | methoni
# Processing Record 10 of Set 10 | la ronge
# Processing Record 11 of Set 10 | mango
# Processing Record 12 of Set 10 | les escoumins
# Processing Record 13 of Set 10 | waiblingen
# Processing Record 14 of Set 10 | otradnoye
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | bela
# Processing Record 17 of Set 10 | conceicao do araguaia
# Processing Record 18 of Set 10 | noyabrsk
# Processing Record 19 of Set 10 | tecoanapa
# Processing Record 20 of Set 10 | batagay
# Processing Record 21 of Set 10 | jumla
# Processing Record 22 of Set 10 | karlskoga
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | bengkulu
# Processing Record 25 of Set 10 | rio gallegos
# Processing Record 26 of Set 10 | aripuana
# Processing Record 27 of Set 10 | korem
# Processing Record 28 of Set 10 | kyren
# Processing Record 29 of Set 10 | dakar
# Processing Record 30 of Set 10 | del rio
# Processing Record 31 of Set 10 | lyubytino
# Processing Record 32 of Set 10 | san patricio
# Processing Record 33 of Set 10 | saint-denis
# Processing Record 34 of Set 10 | gonen
# Processing Record 35 of Set 10 | wattegama
# Processing Record 36 of Set 10 | otavi
# Processing Record 37 of Set 10 | severo-kurilsk
# Processing Record 38 of Set 10 | mbinga
# Processing Record 39 of Set 10 | peikang
# City not found. Skipping...
# Processing Record 40 of Set 10 | sept-iles
# Processing Record 41 of Set 10 | hobyo
# Processing Record 42 of Set 10 | ayotzintepec
# Processing Record 43 of Set 10 | atbasar
# Processing Record 44 of Set 10 | krasnyy kholm
# Processing Record 45 of Set 10 | scarborough
# Processing Record 46 of Set 10 | bushehr
# Processing Record 47 of Set 10 | champerico
# Processing Record 48 of Set 10 | katha
# City not found. Skipping...
# Processing Record 49 of Set 10 | mahemdavad
# Processing Record 50 of Set 10 | whitehorse
# Processing Record 1 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 11 | terney
# Processing Record 3 of Set 11 | haines junction
# Processing Record 4 of Set 11 | vohibinany
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | cockburn town
# Processing Record 8 of Set 11 | tessalit
# Processing Record 9 of Set 11 | oyten
# Processing Record 10 of Set 11 | formosa
# Processing Record 11 of Set 11 | suez
# Processing Record 12 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 13 of Set 11 | marmande
# Processing Record 14 of Set 11 | larsnes
# Processing Record 15 of Set 11 | kpandae
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | orange walk
# Processing Record 18 of Set 11 | pizarro
# Processing Record 19 of Set 11 | nerchinskiy zavod
# Processing Record 20 of Set 11 | mantua
# Processing Record 21 of Set 11 | sao filipe
# Processing Record 22 of Set 11 | kavieng
# Processing Record 23 of Set 11 | tynda
# Processing Record 24 of Set 11 | dubbo
# Processing Record 25 of Set 11 | phuket
# Processing Record 26 of Set 11 | turukhansk
# Processing Record 27 of Set 11 | kazanskaya
# Processing Record 28 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 29 of Set 11 | sistranda
# Processing Record 30 of Set 11 | mackay
# Processing Record 31 of Set 11 | picota
# Processing Record 32 of Set 11 | cadillac
# Processing Record 33 of Set 11 | bhusawal
# Processing Record 34 of Set 11 | saquena
# Processing Record 35 of Set 11 | fier
# Processing Record 36 of Set 11 | zheleznodorozhnyy
# Processing Record 37 of Set 11 | cordeiropolis
# Processing Record 38 of Set 11 | hammerfest
# Processing Record 39 of Set 11 | khobi
# Processing Record 40 of Set 11 | ilulissat
# Processing Record 41 of Set 11 | norman wells
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | labuhan
# Processing Record 44 of Set 11 | mandera
# Processing Record 45 of Set 11 | sayyan
# Processing Record 46 of Set 11 | qinhuangdao
# Processing Record 47 of Set 11 | kaniama
# Processing Record 48 of Set 11 | olafsvik
# Processing Record 49 of Set 11 | mahibadhoo
# Processing Record 50 of Set 11 | northam
# Processing Record 1 of Set 12 | tambura
# Processing Record 2 of Set 12 | kousseri
# Processing Record 3 of Set 12 | gidam
# Processing Record 4 of Set 12 | timra
# Processing Record 5 of Set 12 | college
# Processing Record 6 of Set 12 | ust-kuyga
# Processing Record 7 of Set 12 | kavaratti
# Processing Record 8 of Set 12 | machico
# Processing Record 9 of Set 12 | catuday
# Processing Record 10 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 12 | sparks
# Processing Record 12 of Set 12 | konstantinovka
# Processing Record 13 of Set 12 | kurilsk
# Processing Record 14 of Set 12 | polyarnyy
# Processing Record 15 of Set 12 | america dourada
# Processing Record 16 of Set 12 | wanning
# Processing Record 17 of Set 12 | egvekinot
# Processing Record 18 of Set 12 | sakaraha
# Processing Record 19 of Set 12 | cravo norte
# Processing Record 20 of Set 12 | sur
# Processing Record 21 of Set 12 | nago
# Processing Record 22 of Set 12 | areia branca
# Processing Record 23 of Set 12 | sabratah
# Processing Record 24 of Set 12 | clermont
# Processing Record 25 of Set 12 | sangar
# Processing Record 26 of Set 12 | piripiri
# Processing Record 27 of Set 12 | houma
# Processing Record 28 of Set 12 | asind
# Processing Record 29 of Set 12 | troy
# Processing Record 30 of Set 12 | vera cruz
# Processing Record 31 of Set 12 | jatara
# Processing Record 32 of Set 12 | khomutovo
# Processing Record 33 of Set 12 | jutai
# Processing Record 34 of Set 12 | cienaga
# Processing Record 35 of Set 12 | milkovo
# Processing Record 36 of Set 12 | kedrovyy
# Processing Record 37 of Set 12 | salmas
# Processing Record 38 of Set 12 | tura
# Processing Record 39 of Set 12 | luangwa
# Processing Record 40 of Set 12 | myitkyina
# Processing Record 41 of Set 12 | ayan
# Processing Record 42 of Set 12 | kaseda
# Processing Record 43 of Set 12 | salalah
# Processing Record 44 of Set 12 | russell
# Processing Record 45 of Set 12 | nhulunbuy
# Processing Record 46 of Set 12 | caimito
# Processing Record 47 of Set 12 | taltal
# Processing Record 48 of Set 12 | qurayyat
# Processing Record 49 of Set 12 | makurdi
# Processing Record 50 of Set 12 | west wendover
# Processing Record 1 of Set 13 | half moon bay
# Processing Record 2 of Set 13 | dukat
# Processing Record 3 of Set 13 | santa cruz
# Processing Record 4 of Set 13 | baruun-urt
# Processing Record 5 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 13 | lukovetskiy
# Processing Record 7 of Set 13 | amot
# Processing Record 8 of Set 13 | tsevie
# Processing Record 9 of Set 13 | paraiso
# Processing Record 10 of Set 13 | kimbe
# Processing Record 11 of Set 13 | lucea
# Processing Record 12 of Set 13 | yuli
# Processing Record 13 of Set 13 | lebanon
# Processing Record 14 of Set 13 | geraldton
# Processing Record 15 of Set 13 | bucerias
# Processing Record 16 of Set 13 | awbari
# Processing Record 17 of Set 13 | itoman
# Processing Record 18 of Set 13 | okha
# Processing Record 19 of Set 13 | ayios mamas
# Processing Record 20 of Set 13 | churapcha
# Processing Record 21 of Set 13 | mbini
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | cap malheureux
# Processing Record 24 of Set 13 | touros
# Processing Record 25 of Set 13 | talara
# Processing Record 26 of Set 13 | belton
# Processing Record 27 of Set 13 | mweka
# Processing Record 28 of Set 13 | clyde river
# Processing Record 29 of Set 13 | stromness
# Processing Record 30 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 13 | katsuura
# Processing Record 32 of Set 13 | ye
# City not found. Skipping...
# Processing Record 33 of Set 13 | adrar
# Processing Record 34 of Set 13 | linqiong
# Processing Record 35 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 13 | pasni
# Processing Record 37 of Set 13 | velez-malaga
# Processing Record 38 of Set 13 | pouebo
# Processing Record 39 of Set 13 | cotonou
# Processing Record 40 of Set 13 | karatuzskoye
# Processing Record 41 of Set 13 | yaan
# Processing Record 42 of Set 13 | bangsund
# Processing Record 43 of Set 13 | mayor pablo lagerenza
# Processing Record 44 of Set 13 | poum
# Processing Record 45 of Set 13 | namtsy
# Processing Record 46 of Set 13 | nizhniy baskunchak
# Processing Record 47 of Set 13 | dong hoi
# Processing Record 48 of Set 13 | esperance
# Processing Record 49 of Set 13 | goba
# Processing Record 50 of Set 13 | petatlan
# Processing Record 1 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 14 | kasongo
# Processing Record 3 of Set 14 | kholodnyy
# Processing Record 4 of Set 14 | port pirie
# Processing Record 5 of Set 14 | vaitape
# Processing Record 6 of Set 14 | klimovo
# Processing Record 7 of Set 14 | sal rei
# Processing Record 8 of Set 14 | kindu
# Processing Record 9 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 14 | kisangani
# Processing Record 11 of Set 14 | talnakh
# Processing Record 12 of Set 14 | bara
# Processing Record 13 of Set 14 | tiznit
# Processing Record 14 of Set 14 | shimoda
# Processing Record 15 of Set 14 | iberia
# Processing Record 16 of Set 14 | strathmore
# Processing Record 17 of Set 14 | filingue
# Processing Record 18 of Set 14 | tromso
# Processing Record 19 of Set 14 | chitral
# Processing Record 20 of Set 14 | hinton
# Processing Record 21 of Set 14 | brainerd
# Processing Record 22 of Set 14 | saint anthony
# Processing Record 23 of Set 14 | broken hill
# Processing Record 24 of Set 14 | gat
# Processing Record 25 of Set 14 | jalalabad
# Processing Record 26 of Set 14 | coria
# Processing Record 27 of Set 14 | capoterra
# Processing Record 28 of Set 14 | san quintin
# Processing Record 29 of Set 14 | havre
# Processing Record 30 of Set 14 | olean
# Processing Record 31 of Set 14 | la palma
# Processing Record 32 of Set 14 | mecca
# Processing Record 33 of Set 14 | glencoe
# Processing Record 34 of Set 14 | inta
# Processing Record 35 of Set 14 | port hedland
# Processing Record 36 of Set 14 | erenhot
# Processing Record 37 of Set 14 | port macquarie
# Processing Record 38 of Set 14 | biak
# Processing Record 39 of Set 14 | awjilah
# Processing Record 40 of Set 14 | henties bay
# Processing Record 41 of Set 14 | tiarei
# Processing Record 42 of Set 14 | mastic beach
# Processing Record 43 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 14 | havoysund
# Processing Record 45 of Set 14 | khowst
# Processing Record 46 of Set 14 | lensk
# Processing Record 47 of Set 14 | lompoc
# Processing Record 48 of Set 14 | cahir
# Processing Record 49 of Set 14 | mansa
# Processing Record 50 of Set 14 | sobolevo
# Processing Record 1 of Set 15 | rexburg
# Processing Record 2 of Set 15 | soligalich
# Processing Record 3 of Set 15 | arkadak
# Processing Record 4 of Set 15 | rafai
# Processing Record 5 of Set 15 | canavieiras
# Processing Record 6 of Set 15 | nioki
# Processing Record 7 of Set 15 | koshurnikovo
# Processing Record 8 of Set 15 | roebourne
# Processing Record 9 of Set 15 | nazare
# Processing Record 10 of Set 15 | calcutta
# Processing Record 11 of Set 15 | paytug
# City not found. Skipping...
# Processing Record 12 of Set 15 | belize
# Processing Record 13 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 14 of Set 15 | ust-nera
# Processing Record 15 of Set 15 | kamaishi
# Processing Record 16 of Set 15 | tual
# Processing Record 17 of Set 15 | blagoyevo
# Processing Record 18 of Set 15 | mucurapo
# Processing Record 19 of Set 15 | edea
# Processing Record 20 of Set 15 | buraydah
# Processing Record 21 of Set 15 | najran
# Processing Record 22 of Set 15 | lufkin
# Processing Record 23 of Set 15 | tayu
# Processing Record 24 of Set 15 | maues
# Processing Record 25 of Set 15 | baijiantan
# Processing Record 26 of Set 15 | meiganga
# Processing Record 27 of Set 15 | velizh
# Processing Record 28 of Set 15 | puerto varas
# Processing Record 29 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 15 | hauterive
# Processing Record 31 of Set 15 | quang ngai
# Processing Record 32 of Set 15 | general roca
# Processing Record 33 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 15 | motala
# Processing Record 35 of Set 15 | yar-sale
# Processing Record 36 of Set 15 | port-cartier
# Processing Record 37 of Set 15 | guelengdeng
# City not found. Skipping...
# Processing Record 38 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 15 | manbij
# Processing Record 40 of Set 15 | calvinia
# Processing Record 41 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 15 | kostino
# Processing Record 43 of Set 15 | kurtalan
# Processing Record 44 of Set 15 | pankrushikha
# Processing Record 45 of Set 15 | bardiyah
# Processing Record 46 of Set 15 | little current
# Processing Record 47 of Set 15 | the valley
# Processing Record 48 of Set 15 | warwick
# Processing Record 49 of Set 15 | podbelsk
# City not found. Skipping...
# Processing Record 50 of Set 15 | bilibino
# Processing Record 1 of Set 16 | meadow lake
# Processing Record 2 of Set 16 | kysyl-syr
# Processing Record 3 of Set 16 | kilindoni
# Processing Record 4 of Set 16 | karacakoy
# Processing Record 5 of Set 16 | santa marta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Kudahuvadhoo      MV   2.6708   72.8944     80.58        80          99
# 1   Yerbogachen      RU  61.2767  108.0108     52.57        83          68
# 2       Te Anau      NZ -45.4167  167.7167     33.28        87          37
# 3  Punta Arenas      CL -53.1500  -70.9167     37.51        87           0
# 4      Ellisras      ZA -23.6649   27.7443     51.94        44           0
# 5    Carutapera      BR  -1.1950  -46.0200     76.75        85          55
# 6   New Norfolk      AU -42.7826  147.0587     34.72        90          30
# 7      Hermanus      ZA -34.4187   19.2345     53.91        71          17
# 8       Rikitea      PF -23.1203 -134.9692     74.10        68          22
# 9     Maniitsoq      GL  65.4167  -52.9000     45.88        68          46
#
#    Wind Speed Current Description
# 0       17.00     overcast clouds
# 1        5.95       broken clouds
# 2        0.92    scattered clouds
# 3        8.05           clear sky
# 4        3.56           clear sky
# 5        7.65       broken clouds
# 6        2.37    scattered clouds
# 7       12.48          few clouds
# 8       16.33          few clouds
# 9        3.02    scattered clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherPy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
